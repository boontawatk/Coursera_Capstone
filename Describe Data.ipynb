# %% [markdown]
# I can use a district data of Thailand which contains latitude and longtitude of each district to cluster the area and count number of place like this using Foursquare API which scope data in some categories.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# This is data which contains data of sub-district location in Thailand (I already translate columns name to English)

# %%
df=pd.read_excel("Thailand_location.xlsx")
df.head()
# Out:
#   Sub-district  District_ID       District  Province_ID Province     LAT  \
# 0     Ko Sarai         9101   Mueang Satun           91    Satun   6.546
# 1    Maptaphut         2101  Mueang Rayong           21   Rayong  12.646
# 2    Maptaphut         2101  Mueang Rayong           21   Rayong  12.645
# 3    Maptaphut         2101  Mueang Rayong           21   Rayong  12.649
# 4    Maptaphut         2101  Mueang Rayong           21   Rayong  12.644
#
#       LONG
# 0   99.706
# 1  101.171
# 2  101.170
# 3  101.174
# 4  101.169

# %% [markdown]
# I had to filter it to contains only district in Bangkok and made an assumption that mean of latitude and longitude is the center of each district

# %%
df_usable=df[df["Province"]=="Bangkok"].groupby("District").mean()
print(df_usable.shape)
df_usable
# Out:
# (50, 4)
#                      District_ID  Province_ID        LAT        LONG
# District
# Bang Bon                    1050           10  13.646000  100.370000
# Bang Kapi                   1006           10  13.771000  100.647500
# Bang Khae                   1040           10  13.710500  100.397500
# Bang Khen                   1005           10  13.867000  100.628000
# Bang Kho Laem               1031           10  13.698667  100.506000
# Bang Khun Thian             1021           10  13.580000  100.414500
# Bang Na                     1047           10  13.672000  100.616000
# Bang Phlat                  1025           10  13.787000  100.493250
# Bang Rak                    1004           10  13.728000  100.523200
# Bang Su                     1029           10  13.820000  100.529000
# Bangkok Noi                 1020           10  13.763400  100.472800
# Bangkok Yai                 1016           10  13.738000  100.480500
# Bung Kum                    1027           10  13.808000  100.650000
# Chatuchak                   1030           10  13.826000  100.565000
# Chom Thong                  1035           10  13.690250  100.465500
# Din Daeng                   1026           10  13.778000  100.567000
# Don Mueang                  1036           10  13.925000  100.593000
# Dusit                       1002           10  13.772800  100.515400
# Huai Khwang                 1017           10  13.772333  100.580667
# Khanna Yao                  1043           10  13.821000  100.677000
# Khlong Sam Wa               1046           10  13.867800  100.739800
# Khlong San                  1018           10  13.726500  100.502500
# Khlong Toei                 1033           10  13.713333  100.578667
# Lak Si                      1041           10  13.877000  100.572000
# Lat Krabang                 1011           10  13.743000  100.789167
# Lat Phrao                   1038           10  13.825500  100.606000
# Min Buri                    1010           10  13.808000  100.748500
# Nong Chok                   1003           10  13.851250  100.856125
# Nong Khaem                  1023           10  13.697000  100.354500
# Pathum Wan                  1007           10  13.740500  100.531750
# Phasi Charoen               1022           10  13.726714  100.445571
# Phaya Thai                  1014           10  13.782000  100.545000
# Phra Khanong                1009           10  13.692000  100.626000
# Phra Nakhon                 1001           10  13.756417  100.499250
# Pom Prap Sattruphai         1008           10  13.751200  100.511400
# Prawet                      1032           10  13.695333  100.669667
# Rat Burana                  1024           10  13.672500  100.500500
# Rat Thewi                   1037           10  13.756000  100.538750
# Sa Thon                     1028           10  13.714000  100.529000
# Sai Mai                     1042           10  13.905000  100.652000
# Samphanthawong              1013           10  13.738000  100.509333
# Saphan Sung                 1044           10  13.761000  100.688000
# Suan Luang                  1034           10  13.726000  100.628000
# Taling Chan                 1019           10  13.767500  100.439833
# Thawi Watthana              1048           10  13.770500  100.369000
# Thon Buri                   1015           10  13.722000  100.484800
# Thung Khu                   1049           10  13.632500  100.503500
# Wang Thong Lang             1045           10  13.779000  100.609000
# Watthana                    1039           10  13.732667  100.577333
# Yannawa                     1012           10  13.689500  100.538500
